# %%
import cPickle as pickle
n_layers = 1
parameters, states = pickle.load(open('parameters/plain-network-on-shrinked-mnist-%d' % n_layers, 'rb'))

# %%
import numpy as np
pre = np.abs
import matplotlib.pylab as pl
# %matplotlib inline
f, axes = pl.subplots(2, 4)
kernels = parameters['convolution0_weight']
for i in range(2):
    for j in range(4):
        axes[i, j].imshow(pre(kernels[i * 2 + j][0]), cmap='gray', interpolation='bilinear')
        axes[i, j].axis('off')
