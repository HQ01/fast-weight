# %%
import cPickle as pickle
import matplotlib.pylab as pl
# %matplotlib inline

# %%
table = pickle.load(open('test_accuracy_without_refinement', 'rb'))

# %%
pl.plot(range(len(table)), table)
pl.title('test accuracy without refinement')
pl.xlabel('refinement modules per transition')
pl.ylabel('test accuracy')
